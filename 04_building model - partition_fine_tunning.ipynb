# %% [markdown]
# ## Building model
# ### Libraries

# %%
# Supress warnings
import warnings
warnings.filterwarnings('ignore')

import os
import matplotlib.pyplot as plt
#import pandas as pd
import seaborn as sns
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import load_model
from keras.regularizers import l2
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %% [markdown]
# ### Loading datasets

# %%
actions = np.array(['adios', 'amor', 'animal',
                    'bienvenida', 'gracias', 'hola', 
                    'hombre', 'internet', 'mujer',
                    'nino_na', 'objeto', 'persona',
                    'radio', 'television', 'tristeza'])

# %%
data_folder='dataset/size_0_3'

X_train=np.load(os.path.join(data_folder, 'X_train.npy'))
X_val=np.load(os.path.join(data_folder, 'X_test.npy'))
y_train=np.load(os.path.join(data_folder, 'y_train.npy'))
y_val=np.load(os.path.join(data_folder, 'y_test.npy'))

# %% [markdown]
# ### Build and Train LSTM Neural Network

# %%
log_dir=os.path.join('Logs/log_pt10_noes')
tb_callback=TensorBoard(log_dir=log_dir)

# %%
# Build the LSTM model with fine tunning

model=Sequential()
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', kernel_regularizer=l2(0.01), input_shape=(30, 1662)))
model.add(Dropout(0.2))  # Dropout para evitar sobreajuste
model.add(LSTM(128, return_sequences=True, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.2))  # Dropout para evitar sobreajuste
model.add(LSTM(64, return_sequences=False, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.2))  # Dropout para evitar sobreajuste
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.2))  # Dropout para evitar sobreajuste
model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
# Summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  dropout (Dropout)           (None, 30, 64)            0
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  dropout_1 (Dropout)         (None, 30, 128)           0
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 15)                495
#
# =================================================================
# Total params: 597071 (2.28 MB)
# Trainable params: 597071 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
# Train the model
history=model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=1200)
# Out:
# Epoch 1/1200
# 10/10 [==============================] - 7s 193ms/step - loss: 10.4419 - categorical_accuracy: 0.0889 - val_loss: 9.4172 - val_categorical_accuracy: 0.0889
# Epoch 2/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 8.9596 - categorical_accuracy: 0.0794 - val_loss: 8.3705 - val_categorical_accuracy: 0.0593
# Epoch 3/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 7.9444 - categorical_accuracy: 0.0889 - val_loss: 7.4632 - val_categorical_accuracy: 0.0444
# Epoch 4/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 7.2096 - categorical_accuracy: 0.0921 - val_loss: 6.8763 - val_categorical_accuracy: 0.1037
# Epoch 5/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 6.6386 - categorical_accuracy: 0.0794 - val_loss: 6.3651 - val_categorical_accuracy: 0.0444
# Epoch 6/1200
# 10/10 [==============================] - 1s 118ms/step - loss: 6.1512 - categorical_accuracy: 0.0921 - val_loss: 5.8867 - val_categorical_accuracy: 0.0519
# Epoch 7/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 5.7865 - categorical_accuracy: 0.1016 - val_loss: 5.6950 - val_categorical_accuracy: 0.1630
# Epoch 8/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 5.5869 - categorical_accuracy: 0.0952 - val_loss: 5.4678 - val_categorical_accuracy: 0.0444
# Epoch 9/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 5.3619 - categorical_accuracy: 0.0698 - val_loss: 5.2575 - val_categorical_accuracy: 0.0444
# Epoch 10/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 5.3177 - categorical_accuracy: 0.0952 - val_loss: 4.9513 - val_categorical_accuracy: 0.0444
# Epoch 11/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 4.9371 - categorical_accuracy: 0.0730 - val_loss: 4.6299 - val_categorical_accuracy: 0.0444
# Epoch 12/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 4.7839 - categorical_accuracy: 0.1206 - val_loss: 4.6027 - val_categorical_accuracy: 0.0444
# Epoch 13/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 4.5443 - categorical_accuracy: 0.1397 - val_loss: 4.3744 - val_categorical_accuracy: 0.1333
# Epoch 14/1200
# 10/10 [==============================] - 1s 129ms/step - loss: 4.3919 - categorical_accuracy: 0.1841 - val_loss: 4.2765 - val_categorical_accuracy: 0.0963
# Epoch 15/1200
# 10/10 [==============================] - 1s 130ms/step - loss: 4.2326 - categorical_accuracy: 0.1905 - val_loss: 4.0845 - val_categorical_accuracy: 0.1556
# Epoch 16/1200
# 10/10 [==============================] - 1s 134ms/step - loss: 4.0740 - categorical_accuracy: 0.2222 - val_loss: 3.9502 - val_categorical_accuracy: 0.1852
# Epoch 17/1200
# 10/10 [==============================] - 1s 128ms/step - loss: 3.9410 - categorical_accuracy: 0.2032 - val_loss: 3.7099 - val_categorical_accuracy: 0.2222
# Epoch 18/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 4.0500 - categorical_accuracy: 0.1873 - val_loss: 4.0936 - val_categorical_accuracy: 0.1259
# Epoch 19/1200
# 10/10 [==============================] - 1s 132ms/step - loss: 3.8280 - categorical_accuracy: 0.1968 - val_loss: 3.7212 - val_categorical_accuracy: 0.1926
# Epoch 20/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 3.6628 - categorical_accuracy: 0.2032 - val_loss: 3.5428 - val_categorical_accuracy: 0.2519
# Epoch 21/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 3.5555 - categorical_accuracy: 0.2349 - val_loss: 3.3965 - val_categorical_accuracy: 0.2000
# Epoch 22/1200
# 10/10 [==============================] - 1s 130ms/step - loss: 3.6843 - categorical_accuracy: 0.1746 - val_loss: 3.4828 - val_categorical_accuracy: 0.2370
# Epoch 23/1200
# 10/10 [==============================] - 1s 131ms/step - loss: 3.5007 - categorical_accuracy: 0.1968 - val_loss: 3.3201 - val_categorical_accuracy: 0.1259
# Epoch 24/1200
# 10/10 [==============================] - 1s 132ms/step - loss: 3.3398 - categorical_accuracy: 0.2698 - val_loss: 3.2121 - val_categorical_accuracy: 0.2741
# Epoch 25/1200
# 10/10 [==============================] - 1s 132ms/step - loss: 3.1689 - categorical_accuracy: 0.2571 - val_loss: 3.1227 - val_categorical_accuracy: 0.1333
# Epoch 26/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 3.0702 - categorical_accuracy: 0.2508 - val_loss: 2.8214 - val_categorical_accuracy: 0.3926
# Epoch 27/1200
# 10/10 [==============================] - 1s 129ms/step - loss: 3.0281 - categorical_accuracy: 0.2794 - val_loss: 2.8979 - val_categorical_accuracy: 0.2296
# Epoch 28/1200
# 10/10 [==============================] - 1s 133ms/step - loss: 3.1290 - categorical_accuracy: 0.2190 - val_loss: 2.9356 - val_categorical_accuracy: 0.2370
# Epoch 29/1200
# 10/10 [==============================] - 1s 134ms/step - loss: 2.9083 - categorical_accuracy: 0.3048 - val_loss: 2.8411 - val_categorical_accuracy: 0.2963
# Epoch 30/1200
# 10/10 [==============================] - 1s 131ms/step - loss: 2.8055 - categorical_accuracy: 0.3111 - val_loss: 2.8918 - val_categorical_accuracy: 0.2000
# Epoch 31/1200
# 10/10 [==============================] - 1s 130ms/step - loss: 2.7307 - categorical_accuracy: 0.3206 - val_loss: 2.7234 - val_categorical_accuracy: 0.2222
# Epoch 32/1200
# 10/10 [==============================] - 1s 129ms/step - loss: 2.6832 - categorical_accuracy: 0.3143 - val_loss: 2.6692 - val_categorical_accuracy: 0.1926
# Epoch 33/1200
# 10/10 [==============================] - 1s 128ms/step - loss: 2.6582 - categorical_accuracy: 0.2889 - val_loss: 2.7763 - val_categorical_accuracy: 0.1704
# Epoch 34/1200
# 10/10 [==============================] - 1s 128ms/step - loss: 2.7806 - categorical_accuracy: 0.2603 - val_loss: 2.5749 - val_categorical_accuracy: 0.3259
# Epoch 35/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 2.7697 - categorical_accuracy: 0.2635 - val_loss: 2.4949 - val_categorical_accuracy: 0.2444
# Epoch 36/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 2.6489 - categorical_accuracy: 0.2794 - val_loss: 2.4705 - val_categorical_accuracy: 0.3111
# Epoch 37/1200
# 10/10 [==============================] - 1s 129ms/step - loss: 2.4844 - categorical_accuracy: 0.3175 - val_loss: 2.5514 - val_categorical_accuracy: 0.2148
# Epoch 38/1200
# 10/10 [==============================] - 1s 131ms/step - loss: 2.4149 - categorical_accuracy: 0.2794 - val_loss: 2.3521 - val_categorical_accuracy: 0.3037
# Epoch 39/1200
# 10/10 [==============================] - 1s 132ms/step - loss: 2.3029 - categorical_accuracy: 0.3429 - val_loss: 2.6711 - val_categorical_accuracy: 0.1407
# Epoch 40/1200
# 10/10 [==============================] - 1s 129ms/step - loss: 2.2774 - categorical_accuracy: 0.3143 - val_loss: 2.1474 - val_categorical_accuracy: 0.3630
# Epoch 41/1200
# 10/10 [==============================] - 1s 132ms/step - loss: 2.2145 - categorical_accuracy: 0.3778 - val_loss: 2.4594 - val_categorical_accuracy: 0.3778
# Epoch 42/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 2.2240 - categorical_accuracy: 0.3651 - val_loss: 2.1702 - val_categorical_accuracy: 0.2741
# Epoch 43/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 2.1034 - categorical_accuracy: 0.3937 - val_loss: 2.4563 - val_categorical_accuracy: 0.3111
# Epoch 44/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 2.1260 - categorical_accuracy: 0.4063 - val_loss: 2.3925 - val_categorical_accuracy: 0.3259
# Epoch 45/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 2.0912 - categorical_accuracy: 0.3651 - val_loss: 2.4672 - val_categorical_accuracy: 0.1704
# Epoch 46/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 2.1362 - categorical_accuracy: 0.3841 - val_loss: 3.3626 - val_categorical_accuracy: 0.1037
# Epoch 47/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 2.1867 - categorical_accuracy: 0.3492 - val_loss: 2.6499 - val_categorical_accuracy: 0.1926
# Epoch 48/1200
# 10/10 [==============================] - 1s 129ms/step - loss: 2.0035 - categorical_accuracy: 0.3841 - val_loss: 2.3737 - val_categorical_accuracy: 0.2370
# Epoch 49/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.8947 - categorical_accuracy: 0.4190 - val_loss: 2.9886 - val_categorical_accuracy: 0.1926
# Epoch 50/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 1.8438 - categorical_accuracy: 0.4349 - val_loss: 3.1590 - val_categorical_accuracy: 0.1481
# Epoch 51/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.8789 - categorical_accuracy: 0.3937 - val_loss: 3.2810 - val_categorical_accuracy: 0.1185
# Epoch 52/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.8986 - categorical_accuracy: 0.4222 - val_loss: 2.4370 - val_categorical_accuracy: 0.3037
# Epoch 53/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.8311 - categorical_accuracy: 0.4635 - val_loss: 3.2651 - val_categorical_accuracy: 0.1111
# Epoch 54/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.8873 - categorical_accuracy: 0.4444 - val_loss: 2.2454 - val_categorical_accuracy: 0.2593
# Epoch 55/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.7314 - categorical_accuracy: 0.4667 - val_loss: 1.8369 - val_categorical_accuracy: 0.3630
# Epoch 56/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 1.7692 - categorical_accuracy: 0.4413 - val_loss: 2.1053 - val_categorical_accuracy: 0.2963
# Epoch 57/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 1.8532 - categorical_accuracy: 0.4317 - val_loss: 1.7599 - val_categorical_accuracy: 0.4296
# Epoch 58/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.8187 - categorical_accuracy: 0.4127 - val_loss: 2.4988 - val_categorical_accuracy: 0.2000
# Epoch 59/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.6647 - categorical_accuracy: 0.4984 - val_loss: 2.5068 - val_categorical_accuracy: 0.2593
# Epoch 60/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.7624 - categorical_accuracy: 0.4540 - val_loss: 2.8453 - val_categorical_accuracy: 0.1630
# Epoch 61/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.6855 - categorical_accuracy: 0.4667 - val_loss: 1.9736 - val_categorical_accuracy: 0.3259
# Epoch 62/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.7460 - categorical_accuracy: 0.4317 - val_loss: 1.7713 - val_categorical_accuracy: 0.3630
# Epoch 63/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.6513 - categorical_accuracy: 0.4825 - val_loss: 3.6003 - val_categorical_accuracy: 0.0667
# Epoch 64/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.8361 - categorical_accuracy: 0.4317 - val_loss: 2.1694 - val_categorical_accuracy: 0.3185
# Epoch 65/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 1.8685 - categorical_accuracy: 0.4413 - val_loss: 1.6670 - val_categorical_accuracy: 0.4815
# Epoch 66/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.8150 - categorical_accuracy: 0.4349 - val_loss: 2.2111 - val_categorical_accuracy: 0.2519
# Epoch 67/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.6488 - categorical_accuracy: 0.4603 - val_loss: 2.8104 - val_categorical_accuracy: 0.1778
# Epoch 68/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 1.6070 - categorical_accuracy: 0.4730 - val_loss: 1.7231 - val_categorical_accuracy: 0.4370
# Epoch 69/1200
# 10/10 [==============================] - 1s 118ms/step - loss: 1.5095 - categorical_accuracy: 0.5460 - val_loss: 2.4179 - val_categorical_accuracy: 0.2000
# Epoch 70/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.5715 - categorical_accuracy: 0.4921 - val_loss: 1.6479 - val_categorical_accuracy: 0.3852
# Epoch 71/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.7769 - categorical_accuracy: 0.4222 - val_loss: 3.5006 - val_categorical_accuracy: 0.1630
# Epoch 72/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.6732 - categorical_accuracy: 0.4794 - val_loss: 1.6600 - val_categorical_accuracy: 0.3481
# Epoch 73/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.4749 - categorical_accuracy: 0.5619 - val_loss: 2.2812 - val_categorical_accuracy: 0.4148
# Epoch 74/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.5971 - categorical_accuracy: 0.4540 - val_loss: 1.4705 - val_categorical_accuracy: 0.5111
# Epoch 75/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 1.6751 - categorical_accuracy: 0.4603 - val_loss: 2.2304 - val_categorical_accuracy: 0.2889
# Epoch 76/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 1.4993 - categorical_accuracy: 0.5175 - val_loss: 1.9989 - val_categorical_accuracy: 0.2815
# Epoch 77/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.4544 - categorical_accuracy: 0.5206 - val_loss: 1.8820 - val_categorical_accuracy: 0.3407
# Epoch 78/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.4207 - categorical_accuracy: 0.5810 - val_loss: 2.3777 - val_categorical_accuracy: 0.2815
# Epoch 79/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.3641 - categorical_accuracy: 0.6000 - val_loss: 2.5431 - val_categorical_accuracy: 0.2593
# Epoch 80/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.4060 - categorical_accuracy: 0.5270 - val_loss: 2.2559 - val_categorical_accuracy: 0.2370
# Epoch 81/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.3193 - categorical_accuracy: 0.5746 - val_loss: 3.0801 - val_categorical_accuracy: 0.2741
# Epoch 82/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.5589 - categorical_accuracy: 0.5143 - val_loss: 4.0020 - val_categorical_accuracy: 0.1926
# Epoch 83/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.9732 - categorical_accuracy: 0.3524 - val_loss: 2.5803 - val_categorical_accuracy: 0.1704
# Epoch 84/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.8838 - categorical_accuracy: 0.3905 - val_loss: 2.3326 - val_categorical_accuracy: 0.3259
# Epoch 85/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.6952 - categorical_accuracy: 0.4413 - val_loss: 1.6419 - val_categorical_accuracy: 0.3852
# Epoch 86/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 1.5697 - categorical_accuracy: 0.4952 - val_loss: 2.2509 - val_categorical_accuracy: 0.2074
# Epoch 87/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.5253 - categorical_accuracy: 0.5270 - val_loss: 1.5092 - val_categorical_accuracy: 0.4370
# Epoch 88/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.4660 - categorical_accuracy: 0.5302 - val_loss: 1.9239 - val_categorical_accuracy: 0.3704
# Epoch 89/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.3369 - categorical_accuracy: 0.5587 - val_loss: 2.1952 - val_categorical_accuracy: 0.4000
# Epoch 90/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.3080 - categorical_accuracy: 0.5841 - val_loss: 1.9345 - val_categorical_accuracy: 0.3259
# Epoch 91/1200
# 10/10 [==============================] - 1s 118ms/step - loss: 1.3134 - categorical_accuracy: 0.5937 - val_loss: 1.8915 - val_categorical_accuracy: 0.4000
# Epoch 92/1200
# 10/10 [==============================] - 1s 118ms/step - loss: 1.4951 - categorical_accuracy: 0.5048 - val_loss: 1.7550 - val_categorical_accuracy: 0.4074
# Epoch 93/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.5595 - categorical_accuracy: 0.5175 - val_loss: 3.3671 - val_categorical_accuracy: 0.2148
# Epoch 94/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 2.0377 - categorical_accuracy: 0.3365 - val_loss: 1.9668 - val_categorical_accuracy: 0.2889
# Epoch 95/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.6697 - categorical_accuracy: 0.4952 - val_loss: 1.8117 - val_categorical_accuracy: 0.3259
# Epoch 96/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.5057 - categorical_accuracy: 0.5016 - val_loss: 1.6292 - val_categorical_accuracy: 0.4074
# Epoch 97/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.4908 - categorical_accuracy: 0.5143 - val_loss: 1.6134 - val_categorical_accuracy: 0.3926
# Epoch 98/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.3167 - categorical_accuracy: 0.5587 - val_loss: 2.0749 - val_categorical_accuracy: 0.4222
# Epoch 99/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.2446 - categorical_accuracy: 0.5810 - val_loss: 1.6968 - val_categorical_accuracy: 0.4593
# Epoch 100/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.2414 - categorical_accuracy: 0.6063 - val_loss: 1.4265 - val_categorical_accuracy: 0.5852
# Epoch 101/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.3131 - categorical_accuracy: 0.5905 - val_loss: 2.3646 - val_categorical_accuracy: 0.3037
# Epoch 102/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.2823 - categorical_accuracy: 0.5778 - val_loss: 1.8475 - val_categorical_accuracy: 0.3185
# Epoch 103/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.2365 - categorical_accuracy: 0.6222 - val_loss: 1.2161 - val_categorical_accuracy: 0.6667
# Epoch 104/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.2437 - categorical_accuracy: 0.5905 - val_loss: 2.0772 - val_categorical_accuracy: 0.3037
# Epoch 105/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.4149 - categorical_accuracy: 0.5048 - val_loss: 1.2991 - val_categorical_accuracy: 0.5037
# Epoch 106/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.3632 - categorical_accuracy: 0.5429 - val_loss: 1.7482 - val_categorical_accuracy: 0.5259
# Epoch 107/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.2529 - categorical_accuracy: 0.6190 - val_loss: 2.0292 - val_categorical_accuracy: 0.4963
# Epoch 108/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.1948 - categorical_accuracy: 0.6317 - val_loss: 1.5206 - val_categorical_accuracy: 0.4667
# Epoch 109/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.1738 - categorical_accuracy: 0.6603 - val_loss: 1.6933 - val_categorical_accuracy: 0.4148
# Epoch 110/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.2437 - categorical_accuracy: 0.6349 - val_loss: 1.1129 - val_categorical_accuracy: 0.6519
# Epoch 111/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.1697 - categorical_accuracy: 0.6286 - val_loss: 1.5891 - val_categorical_accuracy: 0.5407
# Epoch 112/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.0573 - categorical_accuracy: 0.7270 - val_loss: 1.4353 - val_categorical_accuracy: 0.4667
# Epoch 113/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.0391 - categorical_accuracy: 0.6730 - val_loss: 1.3223 - val_categorical_accuracy: 0.5037
# Epoch 114/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.0262 - categorical_accuracy: 0.6984 - val_loss: 1.6614 - val_categorical_accuracy: 0.4148
# Epoch 115/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.2245 - categorical_accuracy: 0.6317 - val_loss: 1.1026 - val_categorical_accuracy: 0.6074
# Epoch 116/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 1.5993 - categorical_accuracy: 0.6190 - val_loss: 2.0690 - val_categorical_accuracy: 0.3259
# Epoch 117/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.2293 - categorical_accuracy: 0.6222 - val_loss: 1.2263 - val_categorical_accuracy: 0.6370
# Epoch 118/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 1.2782 - categorical_accuracy: 0.6286 - val_loss: 1.1435 - val_categorical_accuracy: 0.7259
# Epoch 119/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.1958 - categorical_accuracy: 0.6730 - val_loss: 1.3298 - val_categorical_accuracy: 0.5926
# Epoch 120/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.1069 - categorical_accuracy: 0.6984 - val_loss: 1.2814 - val_categorical_accuracy: 0.6148
# Epoch 121/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.1030 - categorical_accuracy: 0.7048 - val_loss: 1.2382 - val_categorical_accuracy: 0.6667
# Epoch 122/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 1.0886 - categorical_accuracy: 0.6635 - val_loss: 1.8765 - val_categorical_accuracy: 0.4370
# Epoch 123/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.2107 - categorical_accuracy: 0.6635 - val_loss: 1.0923 - val_categorical_accuracy: 0.6889
# Epoch 124/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.3001 - categorical_accuracy: 0.5746 - val_loss: 2.6468 - val_categorical_accuracy: 0.5333
# Epoch 125/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.1941 - categorical_accuracy: 0.6349 - val_loss: 2.6500 - val_categorical_accuracy: 0.3037
# Epoch 126/1200
# 10/10 [==============================] - 1s 117ms/step - loss: 1.3135 - categorical_accuracy: 0.6000 - val_loss: 1.4370 - val_categorical_accuracy: 0.5852
# Epoch 127/1200
# 10/10 [==============================] - 1s 117ms/step - loss: 1.1679 - categorical_accuracy: 0.6476 - val_loss: 1.1230 - val_categorical_accuracy: 0.6148
# Epoch 128/1200
# 10/10 [==============================] - 1s 118ms/step - loss: 0.9999 - categorical_accuracy: 0.7397 - val_loss: 1.0308 - val_categorical_accuracy: 0.7037
# Epoch 129/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 4.9169 - categorical_accuracy: 0.1683 - val_loss: 3.1760 - val_categorical_accuracy: 0.0519
# Epoch 130/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 3.2461 - categorical_accuracy: 0.0889 - val_loss: 3.3088 - val_categorical_accuracy: 0.0519
# Epoch 131/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 3.2563 - categorical_accuracy: 0.1175 - val_loss: 3.2512 - val_categorical_accuracy: 0.0815
# Epoch 132/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 3.0477 - categorical_accuracy: 0.1619 - val_loss: 2.8795 - val_categorical_accuracy: 0.1926
# Epoch 133/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 2.7741 - categorical_accuracy: 0.1905 - val_loss: 2.6156 - val_categorical_accuracy: 0.1407
# Epoch 134/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 2.5942 - categorical_accuracy: 0.2222 - val_loss: 2.5234 - val_categorical_accuracy: 0.1630
# Epoch 135/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 2.4169 - categorical_accuracy: 0.2413 - val_loss: 2.3276 - val_categorical_accuracy: 0.1926
# Epoch 136/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 2.7760 - categorical_accuracy: 0.1841 - val_loss: 3.1019 - val_categorical_accuracy: 0.1185
# Epoch 137/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 2.5658 - categorical_accuracy: 0.2095 - val_loss: 2.5350 - val_categorical_accuracy: 0.1704
# Epoch 138/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 2.3907 - categorical_accuracy: 0.2667 - val_loss: 2.2349 - val_categorical_accuracy: 0.3333
# Epoch 139/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 2.2898 - categorical_accuracy: 0.3048 - val_loss: 2.1171 - val_categorical_accuracy: 0.4000
# Epoch 140/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 2.1292 - categorical_accuracy: 0.3429 - val_loss: 2.0262 - val_categorical_accuracy: 0.3852
# Epoch 141/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 2.1619 - categorical_accuracy: 0.3111 - val_loss: 2.0645 - val_categorical_accuracy: 0.3704
# Epoch 142/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 2.0028 - categorical_accuracy: 0.3651 - val_loss: 1.9428 - val_categorical_accuracy: 0.3185
# Epoch 143/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.8984 - categorical_accuracy: 0.3651 - val_loss: 2.1103 - val_categorical_accuracy: 0.3111
# Epoch 144/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.8742 - categorical_accuracy: 0.3619 - val_loss: 2.1675 - val_categorical_accuracy: 0.2296
# Epoch 145/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.7674 - categorical_accuracy: 0.4286 - val_loss: 2.1309 - val_categorical_accuracy: 0.2593
# Epoch 146/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 1.6872 - categorical_accuracy: 0.4667 - val_loss: 1.8285 - val_categorical_accuracy: 0.3556
# Epoch 147/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 1.5950 - categorical_accuracy: 0.5206 - val_loss: 3.5079 - val_categorical_accuracy: 0.1407
# Epoch 148/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.9618 - categorical_accuracy: 0.3556 - val_loss: 1.9775 - val_categorical_accuracy: 0.3185
# Epoch 149/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.7868 - categorical_accuracy: 0.3968 - val_loss: 2.1906 - val_categorical_accuracy: 0.3259
# Epoch 150/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.6170 - categorical_accuracy: 0.5143 - val_loss: 1.7911 - val_categorical_accuracy: 0.4444
# Epoch 151/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.5653 - categorical_accuracy: 0.5111 - val_loss: 2.4733 - val_categorical_accuracy: 0.3037
# Epoch 152/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.5328 - categorical_accuracy: 0.5365 - val_loss: 3.1406 - val_categorical_accuracy: 0.1630
# Epoch 153/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.6529 - categorical_accuracy: 0.5238 - val_loss: 1.6233 - val_categorical_accuracy: 0.4593
# Epoch 154/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.7035 - categorical_accuracy: 0.4508 - val_loss: 2.8180 - val_categorical_accuracy: 0.1852
# Epoch 155/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.6125 - categorical_accuracy: 0.4921 - val_loss: 2.4105 - val_categorical_accuracy: 0.3704
# Epoch 156/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.5748 - categorical_accuracy: 0.4921 - val_loss: 2.9241 - val_categorical_accuracy: 0.1778
# Epoch 157/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 1.6115 - categorical_accuracy: 0.4794 - val_loss: 2.4260 - val_categorical_accuracy: 0.1556
# Epoch 158/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.6676 - categorical_accuracy: 0.4667 - val_loss: 2.4323 - val_categorical_accuracy: 0.2148
# Epoch 159/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.5269 - categorical_accuracy: 0.5333 - val_loss: 2.3481 - val_categorical_accuracy: 0.2593
# Epoch 160/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.4396 - categorical_accuracy: 0.5587 - val_loss: 2.4510 - val_categorical_accuracy: 0.3630
# Epoch 161/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.3716 - categorical_accuracy: 0.6222 - val_loss: 3.3132 - val_categorical_accuracy: 0.2222
# Epoch 162/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.5444 - categorical_accuracy: 0.4984 - val_loss: 2.7793 - val_categorical_accuracy: 0.1556
# Epoch 163/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.4590 - categorical_accuracy: 0.5429 - val_loss: 2.3891 - val_categorical_accuracy: 0.2889
# Epoch 164/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.3591 - categorical_accuracy: 0.5714 - val_loss: 1.6100 - val_categorical_accuracy: 0.5037
# Epoch 165/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.2637 - categorical_accuracy: 0.6159 - val_loss: 2.6561 - val_categorical_accuracy: 0.3704
# Epoch 166/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.4136 - categorical_accuracy: 0.5587 - val_loss: 3.6261 - val_categorical_accuracy: 0.1778
# Epoch 167/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.4601 - categorical_accuracy: 0.5460 - val_loss: 2.4502 - val_categorical_accuracy: 0.3111
# Epoch 168/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.3229 - categorical_accuracy: 0.6063 - val_loss: 2.4136 - val_categorical_accuracy: 0.3926
# Epoch 169/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.2534 - categorical_accuracy: 0.6508 - val_loss: 2.3851 - val_categorical_accuracy: 0.3778
# Epoch 170/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.2127 - categorical_accuracy: 0.6730 - val_loss: 2.4953 - val_categorical_accuracy: 0.3778
# Epoch 171/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 1.2486 - categorical_accuracy: 0.6603 - val_loss: 1.9050 - val_categorical_accuracy: 0.4667
# Epoch 172/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.4066 - categorical_accuracy: 0.5746 - val_loss: 4.1550 - val_categorical_accuracy: 0.1630
# Epoch 173/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.3421 - categorical_accuracy: 0.6063 - val_loss: 2.3132 - val_categorical_accuracy: 0.3185
# Epoch 174/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.3621 - categorical_accuracy: 0.5460 - val_loss: 1.4031 - val_categorical_accuracy: 0.5481
# Epoch 175/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.4569 - categorical_accuracy: 0.5429 - val_loss: 3.1050 - val_categorical_accuracy: 0.2963
# Epoch 176/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.5011 - categorical_accuracy: 0.5397 - val_loss: 2.5305 - val_categorical_accuracy: 0.3630
# Epoch 177/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 1.3867 - categorical_accuracy: 0.5810 - val_loss: 2.7257 - val_categorical_accuracy: 0.3407
# Epoch 178/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.2588 - categorical_accuracy: 0.6635 - val_loss: 2.3224 - val_categorical_accuracy: 0.3704
# Epoch 179/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.1969 - categorical_accuracy: 0.6952 - val_loss: 2.8309 - val_categorical_accuracy: 0.3185
# Epoch 180/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.1551 - categorical_accuracy: 0.6952 - val_loss: 2.6597 - val_categorical_accuracy: 0.3333
# Epoch 181/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.1137 - categorical_accuracy: 0.6889 - val_loss: 2.8231 - val_categorical_accuracy: 0.4370
# Epoch 182/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.1545 - categorical_accuracy: 0.6921 - val_loss: 2.8400 - val_categorical_accuracy: 0.3556
# Epoch 183/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.0626 - categorical_accuracy: 0.7175 - val_loss: 2.5721 - val_categorical_accuracy: 0.4815
# Epoch 184/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.0963 - categorical_accuracy: 0.6984 - val_loss: 3.6058 - val_categorical_accuracy: 0.3630
# Epoch 185/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 1.1432 - categorical_accuracy: 0.6857 - val_loss: 2.7572 - val_categorical_accuracy: 0.4370
# Epoch 186/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.1370 - categorical_accuracy: 0.6857 - val_loss: 2.7226 - val_categorical_accuracy: 0.3778
# Epoch 187/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 1.1247 - categorical_accuracy: 0.7111 - val_loss: 2.1431 - val_categorical_accuracy: 0.4148
# Epoch 188/1200
# 10/10 [==============================] - 1s 129ms/step - loss: 1.0899 - categorical_accuracy: 0.6921 - val_loss: 3.2495 - val_categorical_accuracy: 0.3852
# Epoch 189/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.0586 - categorical_accuracy: 0.7206 - val_loss: 3.0204 - val_categorical_accuracy: 0.2963
# Epoch 190/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.0136 - categorical_accuracy: 0.7397 - val_loss: 2.2149 - val_categorical_accuracy: 0.4889
# Epoch 191/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.1593 - categorical_accuracy: 0.6794 - val_loss: 4.3250 - val_categorical_accuracy: 0.1778
# Epoch 192/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.0947 - categorical_accuracy: 0.6825 - val_loss: 2.1071 - val_categorical_accuracy: 0.5630
# Epoch 193/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 1.1268 - categorical_accuracy: 0.6825 - val_loss: 4.0507 - val_categorical_accuracy: 0.1481
# Epoch 194/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.3138 - categorical_accuracy: 0.6222 - val_loss: 2.2279 - val_categorical_accuracy: 0.3778
# Epoch 195/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 1.5352 - categorical_accuracy: 0.5079 - val_loss: 1.9505 - val_categorical_accuracy: 0.4815
# Epoch 196/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.2305 - categorical_accuracy: 0.6508 - val_loss: 2.3525 - val_categorical_accuracy: 0.4296
# Epoch 197/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.0999 - categorical_accuracy: 0.6762 - val_loss: 2.5487 - val_categorical_accuracy: 0.4370
# Epoch 198/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.0407 - categorical_accuracy: 0.7524 - val_loss: 3.0820 - val_categorical_accuracy: 0.4889
# Epoch 199/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.9486 - categorical_accuracy: 0.7556 - val_loss: 3.4487 - val_categorical_accuracy: 0.3852
# Epoch 200/1200
# 10/10 [==============================] - 1s 129ms/step - loss: 1.0675 - categorical_accuracy: 0.7143 - val_loss: 2.6355 - val_categorical_accuracy: 0.2963
# Epoch 201/1200
# 10/10 [==============================] - 1s 140ms/step - loss: 1.1038 - categorical_accuracy: 0.6825 - val_loss: 3.0300 - val_categorical_accuracy: 0.4444
# Epoch 202/1200
# 10/10 [==============================] - 1s 140ms/step - loss: 0.9955 - categorical_accuracy: 0.7746 - val_loss: 2.8064 - val_categorical_accuracy: 0.4074
# Epoch 203/1200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.9348 - categorical_accuracy: 0.7619 - val_loss: 2.9952 - val_categorical_accuracy: 0.4222
# Epoch 204/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.9834 - categorical_accuracy: 0.7556 - val_loss: 2.4364 - val_categorical_accuracy: 0.4963
# Epoch 205/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.9173 - categorical_accuracy: 0.7746 - val_loss: 2.8429 - val_categorical_accuracy: 0.4444
# Epoch 206/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.9360 - categorical_accuracy: 0.7556 - val_loss: 2.9105 - val_categorical_accuracy: 0.4519
# Epoch 207/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 0.9054 - categorical_accuracy: 0.8000 - val_loss: 2.9272 - val_categorical_accuracy: 0.4444
# Epoch 208/1200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.8294 - categorical_accuracy: 0.7937 - val_loss: 3.7760 - val_categorical_accuracy: 0.4296
# Epoch 209/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.0064 - categorical_accuracy: 0.7397 - val_loss: 2.2568 - val_categorical_accuracy: 0.5185
# Epoch 210/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.0171 - categorical_accuracy: 0.7143 - val_loss: 2.7088 - val_categorical_accuracy: 0.3333
# Epoch 211/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.9890 - categorical_accuracy: 0.7587 - val_loss: 3.4022 - val_categorical_accuracy: 0.4889
# Epoch 212/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.9563 - categorical_accuracy: 0.7556 - val_loss: 1.6749 - val_categorical_accuracy: 0.5704
# Epoch 213/1200
# 10/10 [==============================] - 1s 127ms/step - loss: 0.8890 - categorical_accuracy: 0.7778 - val_loss: 3.2053 - val_categorical_accuracy: 0.3481
# Epoch 214/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.8431 - categorical_accuracy: 0.7810 - val_loss: 2.4105 - val_categorical_accuracy: 0.4741
# Epoch 215/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.8090 - categorical_accuracy: 0.8317 - val_loss: 3.6059 - val_categorical_accuracy: 0.2963
# Epoch 216/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.9344 - categorical_accuracy: 0.7587 - val_loss: 3.4815 - val_categorical_accuracy: 0.3481
# Epoch 217/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.9226 - categorical_accuracy: 0.7714 - val_loss: 1.7169 - val_categorical_accuracy: 0.5556
# Epoch 218/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.9240 - categorical_accuracy: 0.7746 - val_loss: 2.4885 - val_categorical_accuracy: 0.4593
# Epoch 219/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.8317 - categorical_accuracy: 0.7683 - val_loss: 2.8003 - val_categorical_accuracy: 0.4963
# Epoch 220/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.8527 - categorical_accuracy: 0.7905 - val_loss: 2.8620 - val_categorical_accuracy: 0.4815
# Epoch 221/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.8287 - categorical_accuracy: 0.7873 - val_loss: 3.4140 - val_categorical_accuracy: 0.4000
# Epoch 222/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.9097 - categorical_accuracy: 0.7651 - val_loss: 3.7311 - val_categorical_accuracy: 0.4889
# Epoch 223/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.0269 - categorical_accuracy: 0.7556 - val_loss: 3.1384 - val_categorical_accuracy: 0.3407
# Epoch 224/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.0017 - categorical_accuracy: 0.7365 - val_loss: 2.1820 - val_categorical_accuracy: 0.5259
# Epoch 225/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.8924 - categorical_accuracy: 0.7714 - val_loss: 2.3874 - val_categorical_accuracy: 0.4667
# Epoch 226/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.9664 - categorical_accuracy: 0.7556 - val_loss: 4.2687 - val_categorical_accuracy: 0.2074
# Epoch 227/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.0067 - categorical_accuracy: 0.7397 - val_loss: 2.6437 - val_categorical_accuracy: 0.4074
# Epoch 228/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 0.8702 - categorical_accuracy: 0.7841 - val_loss: 3.1792 - val_categorical_accuracy: 0.4074
# Epoch 229/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.8693 - categorical_accuracy: 0.7714 - val_loss: 2.9149 - val_categorical_accuracy: 0.4815
# Epoch 230/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.8243 - categorical_accuracy: 0.8222 - val_loss: 2.5095 - val_categorical_accuracy: 0.4667
# Epoch 231/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.7652 - categorical_accuracy: 0.8127 - val_loss: 2.2795 - val_categorical_accuracy: 0.4889
# Epoch 232/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.7266 - categorical_accuracy: 0.8349 - val_loss: 3.5370 - val_categorical_accuracy: 0.3852
# Epoch 233/1200
# 10/10 [==============================] - 1s 118ms/step - loss: 0.7728 - categorical_accuracy: 0.8032 - val_loss: 2.0713 - val_categorical_accuracy: 0.5259
# Epoch 234/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.7631 - categorical_accuracy: 0.8063 - val_loss: 1.6155 - val_categorical_accuracy: 0.6074
# Epoch 235/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.7153 - categorical_accuracy: 0.8540 - val_loss: 2.1703 - val_categorical_accuracy: 0.5630
# Epoch 236/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.0241 - categorical_accuracy: 0.7810 - val_loss: 2.8339 - val_categorical_accuracy: 0.3926
# Epoch 237/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.9000 - categorical_accuracy: 0.7746 - val_loss: 2.3646 - val_categorical_accuracy: 0.4519
# Epoch 238/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.1322 - categorical_accuracy: 0.6921 - val_loss: 2.0615 - val_categorical_accuracy: 0.4222
# Epoch 239/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.9542 - categorical_accuracy: 0.7333 - val_loss: 1.5976 - val_categorical_accuracy: 0.6074
# Epoch 240/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.9083 - categorical_accuracy: 0.7968 - val_loss: 114.8975 - val_categorical_accuracy: 0.1111
# Epoch 241/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 16.3060 - categorical_accuracy: 0.1714 - val_loss: 4.4944 - val_categorical_accuracy: 0.1037
# Epoch 242/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 7.5341 - categorical_accuracy: 0.0857 - val_loss: 3.5606 - val_categorical_accuracy: 0.0296
# Epoch 243/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 3.6170 - categorical_accuracy: 0.1048 - val_loss: 3.7823 - val_categorical_accuracy: 0.0667
# Epoch 244/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 3.6121 - categorical_accuracy: 0.1016 - val_loss: 3.5634 - val_categorical_accuracy: 0.1185
# Epoch 245/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 3.6810 - categorical_accuracy: 0.1111 - val_loss: 3.7458 - val_categorical_accuracy: 0.0667
# Epoch 246/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 3.8133 - categorical_accuracy: 0.0667 - val_loss: 4.1430 - val_categorical_accuracy: 0.0667
# Epoch 247/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 4.6243 - categorical_accuracy: 0.0825 - val_loss: 3.6885 - val_categorical_accuracy: 0.0519
# Epoch 248/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 4.2720 - categorical_accuracy: 0.0667 - val_loss: 3.6111 - val_categorical_accuracy: 0.0889
# Epoch 249/1200
# 10/10 [==============================] - 1s 118ms/step - loss: 3.5878 - categorical_accuracy: 0.1175 - val_loss: 3.8631 - val_categorical_accuracy: 0.0519
# Epoch 250/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 3.6423 - categorical_accuracy: 0.0730 - val_loss: 3.7490 - val_categorical_accuracy: 0.0519
# Epoch 251/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 3.4930 - categorical_accuracy: 0.1175 - val_loss: 3.4791 - val_categorical_accuracy: 0.0519
# Epoch 252/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 3.3037 - categorical_accuracy: 0.1841 - val_loss: 3.2080 - val_categorical_accuracy: 0.1407
# Epoch 253/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 3.1312 - categorical_accuracy: 0.2222 - val_loss: 3.1461 - val_categorical_accuracy: 0.1333
# Epoch 254/1200
# 10/10 [==============================] - 1s 126ms/step - loss: 3.0471 - categorical_accuracy: 0.2127 - val_loss: 3.0213 - val_categorical_accuracy: 0.1556
# Epoch 255/1200
# 10/10 [==============================] - 1s 131ms/step - loss: 2.9490 - categorical_accuracy: 0.2286 - val_loss: 2.9415 - val_categorical_accuracy: 0.1556
# Epoch 256/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 2.8228 - categorical_accuracy: 0.2381 - val_loss: 2.8783 - val_categorical_accuracy: 0.1185
# Epoch 257/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 2.7206 - categorical_accuracy: 0.2762 - val_loss: 2.7019 - val_categorical_accuracy: 0.2074
# Epoch 258/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 2.6363 - categorical_accuracy: 0.2381 - val_loss: 3.1170 - val_categorical_accuracy: 0.0963
# Epoch 259/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 2.7582 - categorical_accuracy: 0.2127 - val_loss: 2.6072 - val_categorical_accuracy: 0.1852
# Epoch 260/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 2.5794 - categorical_accuracy: 0.2952 - val_loss: 2.7576 - val_categorical_accuracy: 0.1259
# Epoch 261/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 2.5010 - categorical_accuracy: 0.2698 - val_loss: 2.5035 - val_categorical_accuracy: 0.1852
# Epoch 262/1200
# 10/10 [==============================] - 1s 133ms/step - loss: 2.4246 - categorical_accuracy: 0.2984 - val_loss: 2.6024 - val_categorical_accuracy: 0.1481
# Epoch 263/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 2.3490 - categorical_accuracy: 0.3048 - val_loss: 2.7877 - val_categorical_accuracy: 0.0889
# Epoch 264/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 2.3072 - categorical_accuracy: 0.2984 - val_loss: 3.0229 - val_categorical_accuracy: 0.1185
# Epoch 265/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 2.2908 - categorical_accuracy: 0.3048 - val_loss: 3.5714 - val_categorical_accuracy: 0.0519
# Epoch 266/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 2.1975 - categorical_accuracy: 0.3429 - val_loss: 3.5580 - val_categorical_accuracy: 0.0519
# Epoch 267/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 2.1662 - categorical_accuracy: 0.3429 - val_loss: 4.1080 - val_categorical_accuracy: 0.0667
# Epoch 268/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 2.1703 - categorical_accuracy: 0.3270 - val_loss: 3.5769 - val_categorical_accuracy: 0.1037
# Epoch 269/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 2.0638 - categorical_accuracy: 0.3714 - val_loss: 3.3877 - val_categorical_accuracy: 0.1185
# Epoch 270/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 2.1173 - categorical_accuracy: 0.3619 - val_loss: 3.7763 - val_categorical_accuracy: 0.0741
# Epoch 271/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 2.0046 - categorical_accuracy: 0.3810 - val_loss: 4.3876 - val_categorical_accuracy: 0.0593
# Epoch 272/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 2.0130 - categorical_accuracy: 0.3619 - val_loss: 3.8091 - val_categorical_accuracy: 0.0815
# Epoch 273/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.9621 - categorical_accuracy: 0.3841 - val_loss: 4.4095 - val_categorical_accuracy: 0.0815
# Epoch 274/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.9152 - categorical_accuracy: 0.4000 - val_loss: 4.8586 - val_categorical_accuracy: 0.1111
# Epoch 275/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 2.0761 - categorical_accuracy: 0.2794 - val_loss: 3.5643 - val_categorical_accuracy: 0.0593
# Epoch 276/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.9579 - categorical_accuracy: 0.3873 - val_loss: 4.2592 - val_categorical_accuracy: 0.0815
# Epoch 277/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.8553 - categorical_accuracy: 0.4095 - val_loss: 4.9824 - val_categorical_accuracy: 0.0519
# Epoch 278/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 2.0394 - categorical_accuracy: 0.3333 - val_loss: 3.2463 - val_categorical_accuracy: 0.1185
# Epoch 279/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 1.9639 - categorical_accuracy: 0.3873 - val_loss: 4.2707 - val_categorical_accuracy: 0.0593
# Epoch 280/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.9211 - categorical_accuracy: 0.3873 - val_loss: 5.8111 - val_categorical_accuracy: 0.0519
# Epoch 281/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.8635 - categorical_accuracy: 0.3810 - val_loss: 4.7948 - val_categorical_accuracy: 0.0519
# Epoch 282/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.8612 - categorical_accuracy: 0.4190 - val_loss: 3.4568 - val_categorical_accuracy: 0.0963
# Epoch 283/1200
# ...
# Epoch 1108/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5394 - categorical_accuracy: 0.8698 - val_loss: 5.1124 - val_categorical_accuracy: 0.3111
# Epoch 1109/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.5372 - categorical_accuracy: 0.8508 - val_loss: 5.4674 - val_categorical_accuracy: 0.2963
# Epoch 1110/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4587 - categorical_accuracy: 0.8952 - val_loss: 6.9834 - val_categorical_accuracy: 0.2593
# Epoch 1111/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5731 - categorical_accuracy: 0.8698 - val_loss: 5.5115 - val_categorical_accuracy: 0.2815
# Epoch 1112/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.4458 - categorical_accuracy: 0.8921 - val_loss: 5.0266 - val_categorical_accuracy: 0.3259
# Epoch 1113/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.4368 - categorical_accuracy: 0.8857 - val_loss: 4.9740 - val_categorical_accuracy: 0.3407
# Epoch 1114/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.4510 - categorical_accuracy: 0.8889 - val_loss: 6.6712 - val_categorical_accuracy: 0.2963
# Epoch 1115/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.5110 - categorical_accuracy: 0.8667 - val_loss: 5.9512 - val_categorical_accuracy: 0.2815
# Epoch 1116/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4963 - categorical_accuracy: 0.8825 - val_loss: 6.0950 - val_categorical_accuracy: 0.2741
# Epoch 1117/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.7415 - categorical_accuracy: 0.8032 - val_loss: 5.0765 - val_categorical_accuracy: 0.3778
# Epoch 1118/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.1515 - categorical_accuracy: 0.6984 - val_loss: 5.4246 - val_categorical_accuracy: 0.2074
# Epoch 1119/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 1.9453 - categorical_accuracy: 0.4286 - val_loss: 3.6045 - val_categorical_accuracy: 0.0741
# Epoch 1120/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 2.0412 - categorical_accuracy: 0.4190 - val_loss: 2.7937 - val_categorical_accuracy: 0.0889
# Epoch 1121/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 1.5760 - categorical_accuracy: 0.5968 - val_loss: 2.4719 - val_categorical_accuracy: 0.3111
# Epoch 1122/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.2117 - categorical_accuracy: 0.7492 - val_loss: 2.4306 - val_categorical_accuracy: 0.3481
# Epoch 1123/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 1.0596 - categorical_accuracy: 0.8063 - val_loss: 3.6402 - val_categorical_accuracy: 0.2963
# Epoch 1124/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 1.0075 - categorical_accuracy: 0.7714 - val_loss: 3.8677 - val_categorical_accuracy: 0.3185
# Epoch 1125/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 1.1499 - categorical_accuracy: 0.7238 - val_loss: 3.6928 - val_categorical_accuracy: 0.2889
# Epoch 1126/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.9656 - categorical_accuracy: 0.7683 - val_loss: 3.5517 - val_categorical_accuracy: 0.3185
# Epoch 1127/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.9679 - categorical_accuracy: 0.7524 - val_loss: 3.4416 - val_categorical_accuracy: 0.2741
# Epoch 1128/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.7969 - categorical_accuracy: 0.8635 - val_loss: 4.2368 - val_categorical_accuracy: 0.2963
# Epoch 1129/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.7331 - categorical_accuracy: 0.8286 - val_loss: 4.0904 - val_categorical_accuracy: 0.2963
# Epoch 1130/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.7274 - categorical_accuracy: 0.8095 - val_loss: 4.3794 - val_categorical_accuracy: 0.2593
# Epoch 1131/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 0.6460 - categorical_accuracy: 0.8603 - val_loss: 5.5235 - val_categorical_accuracy: 0.2889
# Epoch 1132/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.6502 - categorical_accuracy: 0.8635 - val_loss: 4.6132 - val_categorical_accuracy: 0.2963
# Epoch 1133/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.6841 - categorical_accuracy: 0.8254 - val_loss: 5.2992 - val_categorical_accuracy: 0.2815
# Epoch 1134/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.6091 - categorical_accuracy: 0.8667 - val_loss: 5.4009 - val_categorical_accuracy: 0.2741
# Epoch 1135/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.6060 - categorical_accuracy: 0.8571 - val_loss: 6.3341 - val_categorical_accuracy: 0.2667
# Epoch 1136/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.6617 - categorical_accuracy: 0.8254 - val_loss: 6.2852 - val_categorical_accuracy: 0.2222
# Epoch 1137/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.7444 - categorical_accuracy: 0.8032 - val_loss: 5.7779 - val_categorical_accuracy: 0.2074
# Epoch 1138/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.6161 - categorical_accuracy: 0.8571 - val_loss: 5.7976 - val_categorical_accuracy: 0.2741
# Epoch 1139/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.5840 - categorical_accuracy: 0.8635 - val_loss: 5.5541 - val_categorical_accuracy: 0.3037
# Epoch 1140/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.5866 - categorical_accuracy: 0.8571 - val_loss: 5.7093 - val_categorical_accuracy: 0.2889
# Epoch 1141/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.6502 - categorical_accuracy: 0.8508 - val_loss: 5.1352 - val_categorical_accuracy: 0.2889
# Epoch 1142/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5991 - categorical_accuracy: 0.8508 - val_loss: 4.5992 - val_categorical_accuracy: 0.3185
# Epoch 1143/1200
# 10/10 [==============================] - 1s 118ms/step - loss: 0.6405 - categorical_accuracy: 0.8444 - val_loss: 5.3813 - val_categorical_accuracy: 0.2444
# Epoch 1144/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.5743 - categorical_accuracy: 0.8413 - val_loss: 5.4633 - val_categorical_accuracy: 0.2444
# Epoch 1145/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.5569 - categorical_accuracy: 0.8571 - val_loss: 4.7026 - val_categorical_accuracy: 0.3037
# Epoch 1146/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.5377 - categorical_accuracy: 0.8667 - val_loss: 4.6615 - val_categorical_accuracy: 0.3185
# Epoch 1147/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.5311 - categorical_accuracy: 0.8603 - val_loss: 5.1039 - val_categorical_accuracy: 0.3037
# Epoch 1148/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5324 - categorical_accuracy: 0.8603 - val_loss: 5.6755 - val_categorical_accuracy: 0.2815
# Epoch 1149/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.5272 - categorical_accuracy: 0.8730 - val_loss: 4.2282 - val_categorical_accuracy: 0.3852
# Epoch 1150/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.6764 - categorical_accuracy: 0.8063 - val_loss: 6.7877 - val_categorical_accuracy: 0.2889
# Epoch 1151/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 1.1324 - categorical_accuracy: 0.7016 - val_loss: 3.9143 - val_categorical_accuracy: 0.2519
# Epoch 1152/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.7110 - categorical_accuracy: 0.8000 - val_loss: 5.2733 - val_categorical_accuracy: 0.1926
# Epoch 1153/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.6608 - categorical_accuracy: 0.8381 - val_loss: 5.1046 - val_categorical_accuracy: 0.2000
# Epoch 1154/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.5770 - categorical_accuracy: 0.8698 - val_loss: 5.0447 - val_categorical_accuracy: 0.2222
# Epoch 1155/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.5258 - categorical_accuracy: 0.8571 - val_loss: 5.3168 - val_categorical_accuracy: 0.2370
# Epoch 1156/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.5162 - categorical_accuracy: 0.8635 - val_loss: 4.8666 - val_categorical_accuracy: 0.2741
# Epoch 1157/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4950 - categorical_accuracy: 0.8540 - val_loss: 4.8632 - val_categorical_accuracy: 0.3037
# Epoch 1158/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4724 - categorical_accuracy: 0.8952 - val_loss: 5.8742 - val_categorical_accuracy: 0.2667
# Epoch 1159/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4726 - categorical_accuracy: 0.8857 - val_loss: 6.4964 - val_categorical_accuracy: 0.2667
# Epoch 1160/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.4350 - categorical_accuracy: 0.9111 - val_loss: 6.8499 - val_categorical_accuracy: 0.2444
# Epoch 1161/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.4709 - categorical_accuracy: 0.8889 - val_loss: 7.8009 - val_categorical_accuracy: 0.1556
# Epoch 1162/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.6909 - categorical_accuracy: 0.8254 - val_loss: 5.3303 - val_categorical_accuracy: 0.2667
# Epoch 1163/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5572 - categorical_accuracy: 0.8540 - val_loss: 5.5186 - val_categorical_accuracy: 0.2741
# Epoch 1164/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4950 - categorical_accuracy: 0.8635 - val_loss: 5.5905 - val_categorical_accuracy: 0.2889
# Epoch 1165/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.6046 - categorical_accuracy: 0.8317 - val_loss: 4.4839 - val_categorical_accuracy: 0.3037
# Epoch 1166/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.5968 - categorical_accuracy: 0.8254 - val_loss: 6.2588 - val_categorical_accuracy: 0.1481
# Epoch 1167/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.6133 - categorical_accuracy: 0.8349 - val_loss: 5.7266 - val_categorical_accuracy: 0.2741
# Epoch 1168/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.5109 - categorical_accuracy: 0.8794 - val_loss: 5.7666 - val_categorical_accuracy: 0.3259
# Epoch 1169/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.4693 - categorical_accuracy: 0.8952 - val_loss: 5.6944 - val_categorical_accuracy: 0.3111
# Epoch 1170/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4726 - categorical_accuracy: 0.8921 - val_loss: 6.8399 - val_categorical_accuracy: 0.2148
# Epoch 1171/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.4583 - categorical_accuracy: 0.8857 - val_loss: 6.0117 - val_categorical_accuracy: 0.2667
# Epoch 1172/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.4725 - categorical_accuracy: 0.8603 - val_loss: 5.6461 - val_categorical_accuracy: 0.3556
# Epoch 1173/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.4816 - categorical_accuracy: 0.8794 - val_loss: 6.0065 - val_categorical_accuracy: 0.2667
# Epoch 1174/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5313 - categorical_accuracy: 0.8540 - val_loss: 6.3602 - val_categorical_accuracy: 0.3111
# Epoch 1175/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.5811 - categorical_accuracy: 0.8254 - val_loss: 4.8453 - val_categorical_accuracy: 0.3407
# Epoch 1176/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.8476 - categorical_accuracy: 0.7556 - val_loss: 5.5029 - val_categorical_accuracy: 0.2815
# Epoch 1177/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.7661 - categorical_accuracy: 0.7683 - val_loss: 5.3890 - val_categorical_accuracy: 0.2815
# Epoch 1178/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.6112 - categorical_accuracy: 0.8381 - val_loss: 3.4859 - val_categorical_accuracy: 0.3556
# Epoch 1179/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.6549 - categorical_accuracy: 0.7968 - val_loss: 3.6270 - val_categorical_accuracy: 0.3926
# Epoch 1180/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 0.4989 - categorical_accuracy: 0.8889 - val_loss: 4.2042 - val_categorical_accuracy: 0.3778
# Epoch 1181/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.5845 - categorical_accuracy: 0.8381 - val_loss: 5.1892 - val_categorical_accuracy: 0.3333
# Epoch 1182/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.6056 - categorical_accuracy: 0.8413 - val_loss: 5.9174 - val_categorical_accuracy: 0.2667
# Epoch 1183/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.9460 - categorical_accuracy: 0.7460 - val_loss: 7.3603 - val_categorical_accuracy: 0.1704
# Epoch 1184/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.6196 - categorical_accuracy: 0.8635 - val_loss: 4.3630 - val_categorical_accuracy: 0.2519
# Epoch 1185/1200
# 10/10 [==============================] - 1s 122ms/step - loss: 0.5114 - categorical_accuracy: 0.8730 - val_loss: 4.4254 - val_categorical_accuracy: 0.2444
# Epoch 1186/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4974 - categorical_accuracy: 0.8635 - val_loss: 4.4034 - val_categorical_accuracy: 0.3259
# Epoch 1187/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.4562 - categorical_accuracy: 0.8635 - val_loss: 5.1564 - val_categorical_accuracy: 0.2741
# Epoch 1188/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.5024 - categorical_accuracy: 0.8635 - val_loss: 5.6836 - val_categorical_accuracy: 0.2296
# Epoch 1189/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.4987 - categorical_accuracy: 0.8571 - val_loss: 5.8349 - val_categorical_accuracy: 0.2296
# Epoch 1190/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 0.5536 - categorical_accuracy: 0.8571 - val_loss: 5.6773 - val_categorical_accuracy: 0.2519
# Epoch 1191/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.6495 - categorical_accuracy: 0.8286 - val_loss: 3.4808 - val_categorical_accuracy: 0.4148
# Epoch 1192/1200
# 10/10 [==============================] - 1s 119ms/step - loss: 0.6594 - categorical_accuracy: 0.8190 - val_loss: 5.0445 - val_categorical_accuracy: 0.2963
# Epoch 1193/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.5677 - categorical_accuracy: 0.8444 - val_loss: 4.3012 - val_categorical_accuracy: 0.3111
# Epoch 1194/1200
# 10/10 [==============================] - 1s 125ms/step - loss: 0.4988 - categorical_accuracy: 0.8825 - val_loss: 4.5749 - val_categorical_accuracy: 0.3407
# Epoch 1195/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5008 - categorical_accuracy: 0.8667 - val_loss: 4.5041 - val_categorical_accuracy: 0.3037
# Epoch 1196/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4621 - categorical_accuracy: 0.8857 - val_loss: 5.2165 - val_categorical_accuracy: 0.2222
# Epoch 1197/1200
# 10/10 [==============================] - 1s 121ms/step - loss: 0.4431 - categorical_accuracy: 0.8794 - val_loss: 5.5086 - val_categorical_accuracy: 0.2593
# Epoch 1198/1200
# 10/10 [==============================] - 1s 120ms/step - loss: 0.4729 - categorical_accuracy: 0.8889 - val_loss: 5.7895 - val_categorical_accuracy: 0.2444
# Epoch 1199/1200
# 10/10 [==============================] - 1s 124ms/step - loss: 0.4387 - categorical_accuracy: 0.9016 - val_loss: 4.3058 - val_categorical_accuracy: 0.3481
# Epoch 1200/1200
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4288 - categorical_accuracy: 0.9048 - val_loss: 5.0825 - val_categorical_accuracy: 0.3333

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./Logs
# Out:
# Reusing TensorBoard on port 6006 (pid 21412), started 8:04:15 ago. (Use '!kill 21412' to kill it.)
#       <iframe id="tensorboard-frame-48de1a632d5c9b69" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-48de1a632d5c9b69");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Obtener las métricas de pérdida y precisión
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy=history.history['categorical_accuracy']
val_accuracy=history.history['val_categorical_accuracy']
epochs = range(1, len(train_loss) + 1)

# Gráfica de pérdida
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Gráfica de precisión
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_accuracy, 'b', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Make Predictions

# %%
res=model.predict(X_val)
# Out:
# 5/5 [==============================] - 1s 45ms/step

# %%
actions[np.argmax(res[0])]
# Out:
# 'animal'

# %%
actions[np.argmax(y_val[0])]
# Out:
# 'animal'

# %% [markdown]
# ## Save Weights
# ### Saving model

# %%
# Check if the directory 'models' already exists
if not os.path.exists("models"):
    os.makedirs("models")

# %%
# Saving the model
model.save("models/sl_model_ver1.h5")

# %% [markdown]
# ### Loading model

# %%
# Path to the model file
model_path="models/sl_model_ver1.h5"

# %%
# Load the model
model=load_model(model_path)

# %%
# Check the structure model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 15)                495
#
# =================================================================
# Total params: 597071 (2.28 MB)
# Trainable params: 597071 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.load_weights(model_path)

# %% [markdown]
# ### Evaluation using Confusion Matrix and Accuracy

# %%
ypred=model.predict(X_val)
# Out:
# 5/5 [==============================] - 0s 45ms/step

# %%
ytrue=np.argmax(y_val, axis=1)
ypred=np.argmax(ypred, axis=1)

# %%
# Calcular la matriz de confusión multilabel
confusion_matrix=multilabel_confusion_matrix(ytrue, ypred)
confusion_matrix
# Out:
# array([[[126,   2],
#         [  1,   6]],
#
#        [[115,   6],
#         [ 14,   0]],
#
#        [[113,  10],
#         [  9,   3]],
#
#        [[128,   1],
#         [  0,   6]],
#
#        [[127,   2],
#         [  6,   0]],
#
#        [[126,   0],
#         [  8,   1]],
#
#        [[ 97,  26],
#         [  3,   9]],
#
#        [[117,   7],
#         [ 11,   0]],
#
#        [[123,   2],
#         [ 10,   0]],
#
#        [[116,   9],
#         [ 10,   0]],
#
#        [[117,  14],
#         [  0,   4]],
#
#        [[124,   1],
#         [  1,   9]],
#
#        [[127,   3],
#         [  5,   0]],
#
#        [[122,   5],
#         [  8,   0]],
#
#        [[122,   2],
#         [  4,   7]]], dtype=int64)

# %%
len(confusion_matrix)
# Out:
# 15

# %%
# Visualización usando Seaborn
plt.figure(figsize=(15, 10))
for i in range(len(confusion_matrix)):
    # Verificar si hay alguna predicción para esta acción
    if np.any(np.array([ytrue == i, ypred == i]).T):
        sns.heatmap(confusion_matrix[i], annot=True, fmt='.0f', cmap='Blues', 
                    xticklabels=['False Positive', 'True Positive'],
                    yticklabels=['True Positive', 'False Positive'])
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title(f'Confusion Matrix for Action "{actions[i]}"')
        plt.show()

# %%
ytrue = np.argmax(y_val, axis=1).tolist()
ypred = model.predict(X_val)
ypred = np.argmax(ypred, axis=1).tolist()
accuracy_score(ytrue, ypred)
# Out:
# 5/5 [==============================] - 0s 39ms/step
# 0.3333333333333333
