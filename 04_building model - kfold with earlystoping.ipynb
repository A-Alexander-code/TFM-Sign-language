# %% [markdown]
# ## Building model
# ### Libraries

# %%
# Supress warnings
import warnings
warnings.filterwarnings('ignore')

import os
import matplotlib.pyplot as plt
#import pandas as pd
import seaborn as sns
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import load_model
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
from sklearn.model_selection import KFold
from keras.callbacks import EarlyStopping

# %% [markdown]
# ### Loading datasets

# %%
actions = np.array(['adios', 'amor', 'animal',
                    'bienvenida', 'gracias', 'hola', 
                    'hombre', 'internet', 'mujer',
                    'nino_na', 'objeto', 'persona',
                    'radio', 'television', 'tristeza'])

# %%
data_folder='dataset/full_data'

X=np.load(os.path.join(data_folder, 'X.npy'))
y=np.load(os.path.join(data_folder, 'y.npy'))

# %% [markdown]
# ### Build and Train LSTM Neural Network

# %%
log_dir=os.path.join('Logs/log_pt10_noes')
tb_callback=TensorBoard(log_dir=log_dir)

# %%
# Build the LSTM model
model=Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
# Summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 15)                495
#
# =================================================================
# Total params: 597071 (2.28 MB)
# Trainable params: 597071 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define los parámetros para la validación cruzada
seed=42
k=5  # Número de folds
kf=KFold(n_splits=k, shuffle=True, random_state=seed)

# %%
# Compile the model
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
# Definir listas para almacenar las métricas de entrenamiento y validación
fold_train_losses=[]
fold_val_losses=[]
fold_train_accuracies=[]
fold_val_accuracies=[]

# %%
# Define EarlyStopping
early_stopping = EarlyStopping(monitor='loss', patience=20, verbose=1, restore_best_weights=True)

# %%
# Iterar sobre los folds
for train_index, val_index in kf.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Entrena el modelo en este fold
    history = model.fit(X_train, y_train, epochs=1500, batch_size=32, verbose=0, validation_data=(X_val, y_val), callbacks=[early_stopping])
    
    # Almacena las métricas de entrenamiento y validación
    fold_train_losses.append(history.history['loss'][-1])  # Final training loss
    fold_val_losses.append(history.history['val_loss'][-1])  # Final validation loss
    fold_train_accuracies.append(history.history['categorical_accuracy'][-1])  # Final training accuracy
    fold_val_accuracies.append(history.history['val_categorical_accuracy'][-1])  # Final validation accuracy
# Out:
# Restoring model weights from the end of the best epoch: 71.
# Epoch 91: early stopping
# Restoring model weights from the end of the best epoch: 62.
# Epoch 82: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 1364.
# Epoch 1384: early stopping
# Restoring model weights from the end of the best epoch: 116.
# Epoch 136: early stopping

# %%
# Calcular las métricas promedio
avg_train_loss=np.mean(fold_train_losses)
avg_val_loss=np.mean(fold_val_losses)
avg_train_accuracy=np.mean(fold_train_accuracies)
avg_val_accuracy=np.mean(fold_val_accuracies)

# %%
print(f"Average Train loss: {np.round(np.mean(avg_train_loss), 4)}")
print(f"Average Validation loss: {np.round(np.mean(avg_val_loss), 4)}")
print(f"Average Train accuracy: {np.round(np.mean(avg_train_accuracy), 4)}")
print(f"Average Validation accuracy: {np.round(np.mean(avg_val_accuracy), 4)}")
# Out:
# Average Train loss: 0.6612
# Average Validation loss: 0.8629
# Average Train accuracy: 0.7656
# Average Validation accuracy: 0.7289

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./Logs
# Out:
# Reusing TensorBoard on port 6006 (pid 21412), started 8:04:15 ago. (Use '!kill 21412' to kill it.)
#       <iframe id="tensorboard-frame-48de1a632d5c9b69" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-48de1a632d5c9b69");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Graficar la pérdida promedio
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Graficar la precisión promedio
plt.figure(figsize=(12, 6))
plt.plot(history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Make Predictions

# %%
res=model.predict(X_val)
# Out:
# 5/5 [==============================] - 1s 39ms/step

# %%
actions[np.argmax(res[0])]
# Out:
# 'objeto'

# %%
actions[np.argmax(y_val[0])]
# Out:
# 'animal'

# %% [markdown]
# ## Save Weights
# ### Saving model

# %%
# Check if the directory 'models' already exists
if not os.path.exists("models"):
    os.makedirs("models")

# %%
# Saving the model
model.save("models/sl_model_ver1.h5")

# %% [markdown]
# ### Loading model

# %%
# Path to the model file
model_path="models/sl_model_ver1.h5"

# %%
# Load the model
model=load_model(model_path)

# %%
# Check the structure model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 15)                495
#
# =================================================================
# Total params: 597071 (2.28 MB)
# Trainable params: 597071 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.load_weights(model_path)

# %% [markdown]
# ### Evaluation using Confusion Matrix and Accuracy

# %%
ypred=model.predict(X_val)
# Out:
# 5/5 [==============================] - 0s 46ms/step

# %%
ytrue=np.argmax(y_val, axis=1)
ypred=np.argmax(ypred, axis=1)

# %%
# Calcular la matriz de confusión multilabel
confusion_matrix=multilabel_confusion_matrix(ytrue, ypred)
confusion_matrix
# Out:
# array([[[128,   0],
#         [  7,   0]],
#
#        [[121,   0],
#         [ 14,   0]],
#
#        [[123,   0],
#         [ 12,   0]],
#
#        [[129,   0],
#         [  6,   0]],
#
#        [[129,   0],
#         [  6,   0]],
#
#        [[126,   0],
#         [  9,   0]],
#
#        [[123,   0],
#         [ 12,   0]],
#
#        [[124,   0],
#         [ 11,   0]],
#
#        [[125,   0],
#         [ 10,   0]],
#
#        [[125,   0],
#         [ 10,   0]],
#
#        [[  0, 131],
#         [  0,   4]],
#
#        [[125,   0],
#         [ 10,   0]],
#
#        [[130,   0],
#         [  5,   0]],
#
#        [[127,   0],
#         [  8,   0]],
#
#        [[124,   0],
#         [ 11,   0]]], dtype=int64)

# %%
len(confusion_matrix)
# Out:
# 15

# %%
# Visualización usando Seaborn
plt.figure(figsize=(15, 10))
for i in range(len(confusion_matrix)):
    # Verificar si hay alguna predicción para esta acción
    if np.any(np.array([ytrue == i, ypred == i]).T):
        sns.heatmap(confusion_matrix[i], annot=True, fmt='.0f', cmap='Blues', 
                    xticklabels=['False Positive', 'True Positive'],
                    yticklabels=['True Positive', 'False Positive'])
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title(f'Confusion Matrix for Action "{actions[i]}"')
        plt.show()

# %%
ytrue = np.argmax(y_val, axis=1).tolist()
ypred = model.predict(X_val)
ypred = np.argmax(ypred, axis=1).tolist()
accuracy_score(ytrue, ypred)
# Out:
# 5/5 [==============================] - 0s 45ms/step
# 0.02962962962962963
